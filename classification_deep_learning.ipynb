# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical
import numpy as np

# %%
data = pd.read_csv("heart_failure.csv")
print('Classes and number of values in the dataset',Counter(data['DEATH_EVENT']))
y = data["DEATH_EVENT"]
x = data.iloc[:,0:-1]
print(x.info())
# Out:
# Classes and number of values in the dataset Counter({0: 203, 1: 96})
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
# dtypes: float64(3), int64(9)
# memory usage: 28.2 KB
# None

# %%
#data preprocessing
x = pd.get_dummies(x)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 23)
ct = StandardScaler()
x_train = ct.fit_transform(x_train)
x_test = ct.transform(x_test)

# %%
#prepare labels for classification
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
#design a model
model = Sequential()
model.add(InputLayer(input_shape = (x_train.shape[1],)))
model.add(Dense(12, activation='relu'))
model.add(Dense(2, activation = "sigmoid"))
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
#train and evaluate model
model.fit(x_train, y_train, epochs = 100, batch_size = 16, verbose = 1)
acc, loss = model.evaluate(x_test, y_test)

#classification report
y_hat = model.predict(x_test, verbose = 0)
y_hat = np.argmax(y_hat, axis = 1)
y_true = np.argmax(y_test, axis = 1)
print(classification_report(y_true, y_hat))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 3s 5ms/step - loss: 1.0612 - accuracy: 0.5173
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9626 - accuracy: 0.5329
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8237 - accuracy: 0.6054
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7935 - accuracy: 0.6540
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7283 - accuracy: 0.6381
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7632 - accuracy: 0.6581
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8414 - accuracy: 0.6126
# Epoch 8/100
# 14/14 [==============================] - ETA: 0s - loss: 0.9654 - accuracy: 0.50 - 0s 2ms/step - loss: 0.7417 - accuracy: 0.6363
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7162 - accuracy: 0.6431
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6986 - accuracy: 0.6607
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6062 - accuracy: 0.7302
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.6544
# Epoch 13/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6142 - accuracy: 0.7008
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6016 - accuracy: 0.7255
# Epoch 15/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5844 - accuracy: 0.7410
# Epoch 16/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5864 - accuracy: 0.7326
# Epoch 17/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6045 - accuracy: 0.7146
# Epoch 18/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5553 - accuracy: 0.7478
# Epoch 19/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5865 - accuracy: 0.7259
# Epoch 20/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5554 - accuracy: 0.7217
# Epoch 21/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5342 - accuracy: 0.7270
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.7622
# Epoch 23/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5010 - accuracy: 0.7555
# Epoch 24/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4639 - accuracy: 0.8037
# Epoch 25/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4863 - accuracy: 0.7887
# Epoch 26/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4836 - accuracy: 0.7942
# Epoch 27/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.7563
# Epoch 28/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4537 - accuracy: 0.7749
# Epoch 29/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4666 - accuracy: 0.7531
# Epoch 30/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4372 - accuracy: 0.7994
# Epoch 31/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4515 - accuracy: 0.7906
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8272
# Epoch 33/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3742 - accuracy: 0.8333
# Epoch 34/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.7508
# Epoch 35/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8248
# Epoch 36/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.8137
# Epoch 37/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4157 - accuracy: 0.7952
# Epoch 38/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3697 - accuracy: 0.8061
# Epoch 39/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8222
# Epoch 40/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8000
# Epoch 41/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4151 - accuracy: 0.7709
# Epoch 42/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4140 - accuracy: 0.8089
# Epoch 43/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4023 - accuracy: 0.8137
# Epoch 44/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3506 - accuracy: 0.8553
# Epoch 45/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8280
# Epoch 46/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3448 - accuracy: 0.8394
# Epoch 47/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3568 - accuracy: 0.8490
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.8430
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3898 - accuracy: 0.8323
# Epoch 50/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4221 - accuracy: 0.7740
# Epoch 51/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8315
# Epoch 52/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.8483
# Epoch 53/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3214 - accuracy: 0.8794
# Epoch 54/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3390 - accuracy: 0.8468
# Epoch 55/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.8677
# Epoch 56/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.8528
# Epoch 57/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8495
# Epoch 58/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3004 - accuracy: 0.8787
# Epoch 59/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8205
# Epoch 60/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.8347
# Epoch 61/100
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8508
# Epoch 62/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2755 - accuracy: 0.8964
# Epoch 63/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3612 - accuracy: 0.8465
# Epoch 64/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2910 - accuracy: 0.8711
# Epoch 65/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2994 - accuracy: 0.8679
# Epoch 66/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3123 - accuracy: 0.8479
# Epoch 67/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3051 - accuracy: 0.8541
# Epoch 68/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3406 - accuracy: 0.8546
# Epoch 69/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3250 - accuracy: 0.8544
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8664
# Epoch 71/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8530
# Epoch 72/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2825 - accuracy: 0.9102
# Epoch 73/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3202 - accuracy: 0.8762
# Epoch 74/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.8554
# Epoch 75/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2943 - accuracy: 0.8921
# Epoch 76/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.9060
# Epoch 77/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8859
# Epoch 78/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3009 - accuracy: 0.8776
# Epoch 79/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2667 - accuracy: 0.8908
# Epoch 80/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2580 - accuracy: 0.8918
# Epoch 81/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2945 - accuracy: 0.8781
# Epoch 82/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3140 - accuracy: 0.8601
# Epoch 83/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2638 - accuracy: 0.8891
# Epoch 84/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2896 - accuracy: 0.8813
# Epoch 85/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.8961
# Epoch 86/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2789 - accuracy: 0.8901
# Epoch 87/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3386 - accuracy: 0.8562
# Epoch 88/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2804 - accuracy: 0.8530
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2625 - accuracy: 0.8879
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2865 - accuracy: 0.8966
# Epoch 91/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2773 - accuracy: 0.8800
# Epoch 92/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2736 - accuracy: 0.8709
# Epoch 93/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2566 - accuracy: 0.8724
# Epoch 94/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2857 - accuracy: 0.8614
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.8794
# Epoch 96/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2830 - accuracy: 0.8801
# Epoch 97/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2740 - accuracy: 0.8945
# Epoch 98/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.8800
# Epoch 99/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2535 - accuracy: 0.9016
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3047 - accuracy: 0.8864
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5085 - accuracy: 0.7667
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        58
#            1       0.72      0.56      0.63        32
#
#     accuracy                           0.77        90
#    macro avg       0.75      0.72      0.73        90
# weighted avg       0.76      0.77      0.76        90
